# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyas-GN/Python-Exercises/blob/main/subplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.subplot(2,2,2)
plt.plot(np.random.randn(10))
plt.show()
plt.subplot(2,2,4)
plt.plot(np.random.randn(10))

plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(10,4))
x=np.arange(10)
ax[0].plot(x,x**2,'b')
ax[0].plot(x,x,'g')
ax[1].plot(x,np.sqrt(x),'r')
plt.show()

# %%
fig,ax = plt.subplots(2,2)
ax[0,0].plot(np.random.randn(4,4))
ax[0,1].plot(np.random.randn(4,4))
ax[1,0].plot(np.random.randn(4,4))
plt.tight_layout()
plt.show()
